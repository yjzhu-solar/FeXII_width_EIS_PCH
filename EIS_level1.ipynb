# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import colors
from matplotlib import ticker
from matplotlib import rcParams
from matplotlib import patches
import xarray as xr
import scipy.io
import astropy.constants as const
rcParams['text.usetex'] = True
rcParams['font.family'] = 'serif'
import pandas as pd
from astropy.io import fits

# %%
hdul = fits.open("../level0/eis_l0_20110306_205926.fits")
hdul.info()
# Out:
# Filename: ../level0/eis_l0_20110306_205926.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     132   ()
#   1  DATA          1 BinTableHDU    312   3R x 25C   [524288I, 524288I, 524288I, 524288I, 1D, 1D, 1D, 1D, 1I, 1I, 1B, 1B, 1B, 1J, 1J, 1I, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E, 1E]

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / Written by IDL:  Wed Jun 10 18:05:38 2020
# BITPIX  =                    8 /
# NAXIS   =                    0 /
# EXTEND  =                    T / File contains extensions
# DATE    = '2020-06-10'         /
# ORIGIN  = 'ISAS    '           / Institute where FITS file was written
# DATA_LEV=                    0 / FITS Level (0, 1, 2)
# DATE_RF0= '2020-06-10T09:05:38.767' / Date and time of Level 0 reformat
# ORIG_RF0= 'ISAS    '           / Institution where Level 0 reformat was done
# VER_RF0 = 'EIS_Lev0_Reformatter $Revision: 391 $' / Fits Level 0 reformatter ver
# DATE_RF1= '        '           / Date and time of Level 1 reformat
# ORIG_RF1= '        '           / Institution where Level 1 reformat was done
# VER_RF1 = '        '           / Fits Level 1 reformatter version no.
# TELESCOP= 'Hinode  '           / Telescope (Solar-B)
# INSTRUME= 'EIS     '           / EUV Imaging Spectrometer
# LONGSTRN= 'OGIP 1.0'           / The OGIP long string convention may be used.
# COMMENT This FITS file may contain long string keyword values that are
# COMMENT continued over multiple keywords.  This convention uses the  '&'
# COMMENT character at the end of a string which is then continued
# COMMENT on subsequent keywords whose name = 'CONTINUE'.
# OBSTITLE= 'Ultra deep exposure coronal hole                                   &'
# CONTINUE  '             ' / Title of the observation
# TARGET  = 'Coronal Hole        ' / Observation region (QS, CH, AR, FS)
# NOAA_NUM=                    0 / Active region NOAA number
# SCI_OBJ = 'CH                                                                 &'
# CONTINUE  '             ' / Target phenomena for this observation
# OBS_DEC = 'Full CCD, 3x600s, 2"x512", preliminary disk observation            &'
# CONTINUE  '             ' / Properties of the observation
# JOIN_SB = 'E         '         / Joint observation indicator
# OBS_NUM =                    0 / Sequential number of Solar-B observation
# JOP_ID  =                    0 / Joint observing program number
# RAST_ACR= 'EL_WHI_CH_limb'     / Raster Acronym
# STUD_ACR= 'EL_WHI_CH_limb      ' / Study Acronym
# LL_ACR  = 'EL_full_CCD_readout' / Line List Acronym
# LL_ID   =                   41 / Line List ID
# STUDY_ID=                  264 / Study ID
# ST_AUTH = 'Enrico Landi        ' / Study Author
# OBSERVER= 'None                          ' / Chief observer name
# PLANNER = 'None                          ' / Name of Chief Planner
# TOHBANS = 'None           '    / Name of RT Tohbans
# DATATYPE= 'Science             ' / Type of data (pixel data or moments)
# TIMESYS = 'UTC     '           / Time system used in FITS file
# MAIN_ID =                  338 / Main ID
# MDPACK  =                    8 / Number of telemetry packets per exposure
# SEQ_NR  =                   82 / Sequence table number
# SLIT_NR =                33017 / Slit number
# SLIT_IND=                    2 / Slit index
# SLIT_ID = '2"      '           / Slit ID
# LL_NR   =                   10 / Line list number
# NWIN    =                    4 / Number of line windows
# REC_TLID=                21515 / Received timeline entry id
# TL_ID   =                21515 / Unique number for each timeline entry
# TL_WRAP = 'False   '           / True if the on-board timeline id has wrapped
# PLAN_TL =                21515 / Timeline id entry generated by the PT
# RAST_ID =                  253 / Unique number for each raster
# FMIR_SS =                    0 / Fine mirror step size (0 for sit-and-stare mode
# NEXP    =                    3 / Number of exposures performed in raster
# RAST_REQ=                    3 / Number of raster exposures required
# NEXP_PRP=                    3 / Number of exposures pr raster position
# NRASTER =                    1 / Number of unique raster positions
# CCDXL   =                 2148 / CCD X-length incl. scan pix
# XWS     =                   50 / HW (Cam) x window start
# XW      =                 1024 / HW (Cam) x window length
# YWS     =                  402 / HW (Cam) y window start
# YW      =                  512 / HW (Cam) y window height
# RREP_REQ=                    1 / Number of raster repeats required
# RREP_PFD=                    1 / Number of raster repeats performed
# SREP_REQ=                    1 / Number of sequence repeats required
# SREP_PFD=                    1 / Number of sequence repeats performed
# DATE_OBS= '2011-03-06T20:59:26.000' / Start date/time of observation
# DATE_END= '2011-03-06T21:29:30.000' / End date/time of observation
# OBT_TIME=           3260160532 / Spacecraft start time (TI (mdp) units)
# OBT_END =           3261084142 / Spacecraft end time (TI (mdp) units)
# CCSDS_OB= '2011-03-06T21:09:34.000' / Time of first CCSDS packet
# CCSDS_EN= '2011-03-06T21:30:50.000' / Time of last CCSDS packet
# CCSDS_TI=            203820311 / Time of last CCSDS packet (TI (dhu) units)
# XCEN    =            -0.773346 / Center pointing (Solar X)
# YCEN    =             -842.672 / Center pointing (Solar Y)
# CMIRR   =                47659 / Coarse mirror position in unknown units
# CRPIX1  =                    1 / Reference pixel in solar-x
# CRPIX2  =                    1 / Reference pixel in solar-y
# CRVAL1  =              1.22665 / Coordinate value of CRPIX1
# CRVAL2  =             -1098.17 / Coordinate value of CRPIX2
# CDELT1  =             -2.00000 / Pixel size in solar-x
# CDELT2  =              1.00000 / Pixel size in solar-y
# CDELT3  =            0.0223000 / Pixel size in wavelength (dispersion)
# CUNIT1  = 'arcsec  '           / Definition of data unit for axis 1
# CUNIT2  = 'arcsec  '           / Definition of data unit for axis 2
# CUNIT3  = 'Angstrom'           / Definition of data unit for axis 3
# CTYPE1  = 'Solar-X '           / Label for axis 1
# CTYPE2  = 'Solar-Y '           / Label for axis 2
# CTYPE3  = 'Wavelength'         / Label for axis 3
# TR_MODE = 'TR1     '           / Spacecraft/instrument tracking mode
# INST_ROT=              0.00000 / Instrument rotation angle
# SAT_ROT =          0.000128746 / Satellite rotation angle
# CROTA1  =          0.000128746 / INST_ROT + SAT_ROT
# CROTA2  =          0.000128746 / INST_ROT + SAT_ROT
# FOVX    =              2.00000 / Field of view in Solar X (arcsec)
# FOVY    =              512.000 / Field of view in Solar Y (arcsec)
# EISTFLXS=                    1 / Sign - EIS Transl. of XRT Flare X (0=Pos. 1=Neg
# EISTXFLX=                32767 / EIS Transl. of XRT Flare X-coord. (arcsec)
# EISTFLYS=                    1 / Sign - EIS Transl of XRT Flare Y (0=Pos. 1= Neg
# EISTXFLY=                32767 / EIS Transl. of XRT Flare Y-coord. (arcsec)
# EISFLTX =                65535 / EIS flare trigger X-coordinate
# EISFLTY =                65535 / EIS flare trigger Y-coordinate
# EISEVTX =                65535 / EIS event trigger X-location
# EISEVTY =                65535 / EIS event trigger Y-coordinate
# ASRCDIR =                    0 / Anti Solar Rot. Comp. dir. (0=forw, 1=backw)
# ASRCNR  =                    0 / ASRC number of FMIR steps
# ASRCSKIP=                    0 / ASRC frequency
# CAL_DC  =                    0 / Calibration status (Dark Current). 0 = not done
# CAL_HP  =                    0 / Calibration status (Hot pixels). 0 = not done,
# CAL_DP  =                    0 / Calibration status (Dusty pixels). 0 = not done
# CAL_CR  =                    0 / Calibration status (Cosmic rays). 0 = not done,
# CAL_ABS =                    0 / Calibration status (Photometric). 0 = not done,
# CAL_PHOT=                    0 / Calibration status (Photons). 0 = not done, 1 =
# CAL_RETA=                    0 / Calibration status (Retain pixels less than 0).
# BITC_VER=                    7 / Bit compression mode
# COMPMOD =                    7 / Image compression mode
# ACHF_VER=                    1 / Huffman AC table
# DCHF_VER=                    1 / Huffman DC table
# QTAB_VER=                    1 / Quantization table
# SAA     = 'NA      '           / Indicates if satellite is in SAA or not
# HLZ     = 'NA      '           / Indicates if satellite is in HLZ or not
# XOCB    =                    1 / On chip binning x-dir
# YOCB    =                    1 / On chip binning y-dir
# RONCCDAR=                    T / CCD-A Right read out node selected
# RONCCDAL=                    T / CCD-A Left read out node selected
# RONCCDBR=                    T / CCD-B Right read out node selected
# RONCCDBL=                    T / CCD-B Left read out node selected
# XRTFLTR =                    F / XRT Flare Trigger Status (T enabled, F disabled
# EISAEC  =                    F / EIS AEC Status (T enabled, F disabled)
# EISEVTR =                    F / EIS Event Trigger Status (T enabled, F disabled
# EISFLTR =                    F / EIS Flare Trigger Status (T enabled, F disabled
# RESCUED =                    F / Missing or corrupted data (T or F)

# %%
data = hdul[1].data

# %%
data[1][0].shape
# Out:
# (512, 1024)

# %%
fig, ax = plt.subplots(figsize = (16,8))
plt.imshow(np.log10(data[2][1]),origin = 'lower')
plt.savefig(fname = '../figs/level0_window2.png', dpi = 300, format = 'png')

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / Written by IDL:  Wed Jun 10 17:46:25 2020
# BITPIX  =                    8 /
# NAXIS   =                    0 /
# NAXIS1  =              8388693 / Number of bytes per row
# EXTEND  =                    T / File contains extensions
# DATE    = '2020-06-10'         /
# ORIGIN  = 'ISAS    '           / Institute where FITS file was written
# DATA_LEV=                    1 / FITS Level (0, 1, 2)
# DATE_RF0= '2020-06-10T08:46:25.568' / Date and time of Level 0 reformat
# ORIG_RF0= 'ISAS    '           / Institution where Level 0 reformat was done
# VER_RF0 = 'EIS_Lev0_Reformatter $Revision: 391 $' / Fits Level 0 reformatter ver
# DATE_RF1= '2020-06-16T14:10:42.612' / Date and time of Level 1 reformat
# ORIG_RF1= 'ITA-UiO '           / Institution where Level 1 reformat was done
# VER_RF1 = 'EIS_prep Ver $Revision: 748 $' / Fits Level 1 reformatter version no.
# TELESCOP= 'Hinode  '           / Telescope (Solar-B)
# INSTRUME= 'EIS     '           / EUV Imaging Spectrometer
# LONGSTRN= 'OGIP 1.0'           / The OGIP long string convention may be used.
# COMMENT This FITS file may contain long string keyword values that are
# COMMENT continued over multiple keywords.  This convention uses the  '&'
# COMMENT character at the end of a string which is then continued
# COMMENT on subsequent keywords whose name = 'CONTINUE'.
# OBSTITLE= 'Ultra deep exposure coronal hole                                   &'
# CONTINUE  '             ' / Title of the observation
# TARGET  = 'Coronal Hole        ' / Observation region (QS, CH, AR, FS)
# NOAA_NUM=                    0 / Active region NOAA number
# SCI_OBJ = 'CH                                                                 &'
# CONTINUE  '             ' / Target phenomena for this observation
# OBS_DEC = 'Full CCD, 3x600s, 2"x512", 27 reps off disk                        &'
# CONTINUE  '             ' / Properties of the observation
# JOIN_SB = 'E         '         / Joint observation indicator
# OBS_NUM =                    0 / Sequential number of Solar-B observation
# JOP_ID  =                    0 / Joint observing program number
# RAST_ACR= 'EL_WHI_CH_limb'     / Raster Acronym
# STUD_ACR= 'EL_WHI_CH_limb      ' / Study Acronym
# LL_ACR  = 'EL_full_CCD_readout' / Line List Acronym
# LL_ID   =                   41 / Line List ID
# STUDY_ID=                  264 / Study ID
# ST_AUTH = 'Enrico Landi        ' / Study Author
# OBSERVER= 'None                          ' / Chief observer name
# PLANNER = 'None                          ' / Name of Chief Planner
# TOHBANS = 'None           '    / Name of RT Tohbans
# DATATYPE= 'Science             ' / Type of data (pixel data or moments)
# TIMESYS = 'UTC     '           / Time system used in FITS file
# MAIN_ID =                  321 / Main ID
# MDPACK  =                    8 / Number of telemetry packets per exposure
# SEQ_NR  =                   19 / Sequence table number
# SLIT_NR =                33027 / Slit number
# SLIT_IND=                    2 / Slit index
# SLIT_ID = '2"      '           / Slit ID
# LL_NR   =                   13 / Line list number
# NWIN    =                    4 / Number of line windows
# REC_TLID=                21513 / Received timeline entry id
# TL_ID   =                21513 / Unique number for each timeline entry
# TL_WRAP = 'False   '           / True if the on-board timeline id has wrapped
# PLAN_TL =                21513 / Timeline id entry generated by the PT
# RAST_ID =                  253 / Unique number for each raster
# FMIR_SS =                    0 / Fine mirror step size (0 for sit-and-stare mode
# NEXP    =                    3 / Number of exposures performed in raster
# RAST_REQ=                    3 / Number of raster exposures required
# NEXP_PRP=                    3 / Number of exposures pr raster position
# NRASTER =                    1 / Number of unique raster positions
# CCDXL   =                 2148 / CCD X-length incl. scan pix
# XWS     =                   50 / HW (Cam) x window start
# XW      =                 1024 / HW (Cam) x window length
# YWS     =                    2 / HW (Cam) y window start
# YW      =                  512 / HW (Cam) y window height
# RREP_REQ=                   20 / Number of raster repeats required
# RREP_PFD=                   11 / Number of raster repeats performed
# SREP_REQ=                    1 / Number of sequence repeats required
# SREP_PFD=                    1 / Number of sequence repeats performed
# DATE_OBS= '2011-03-06T00:05:01.000' / Start date/time of observation
# DATE_END= '2011-03-06T00:35:05.000' / End date/time of observation
# OBT_TIME=           3221624572 / Spacecraft start time (TI (mdp) units)
# OBT_END =           3222548285 / Spacecraft end time (TI (mdp) units)
# CCSDS_OB= '2011-03-06T00:15:09.000' / Time of first CCSDS packet
# CCSDS_EN= '2011-03-06T00:36:25.000' / Time of last CCSDS packet
# CCSDS_TI=            201411810 / Time of last CCSDS packet (TI (dhu) units)
# XCEN    =            -0.618851 / Center pointing (Solar X)
# YCEN    =             -1242.67 / Center pointing (Solar Y)
# CMIRR   =                47659 / Coarse mirror position in unknown units
# CALSTAT = 'DC CR HP WP DP ABS' / Calibration status
# CRPIX1  =                    1 / Reference pixel in solar-x
# CRPIX2  =                    1 / Reference pixel in solar-y
# CRVAL1  =              1.38115 / Coordinate value of CRPIX1
# CRVAL2  =             -1498.17 / Coordinate value of CRPIX2
# CDELT1  =             -2.00000 / Pixel size in solar-x
# CDELT2  =              1.00000 / Pixel size in solar-y
# CDELT3  =            0.0223000 / Pixel size in wavelength (dispersion)
# CUNIT1  = 'arcsec  '           / Definition of data unit for axis 1
# CUNIT2  = 'arcsec  '           / Definition of data unit for axis 2
# CUNIT3  = 'Angstrom'           / Definition of data unit for axis 3
# CTYPE1  = 'Solar-X '           / Label for axis 1
# CTYPE2  = 'Solar-Y '           / Label for axis 2
# CTYPE3  = 'Wavelength'         / Label for axis 3
# TR_MODE = 'FIX     '           / Spacecraft/instrument tracking mode
# INST_ROT=              0.00000 / Instrument rotation angle
# SAT_ROT =              360.000 / Satellite rotation angle
# CROTA1  =              360.000 / INST_ROT + SAT_ROT
# CROTA2  =              360.000 / INST_ROT + SAT_ROT
# FOVX    =              2.00000 / Field of view in Solar X (arcsec)
# FOVY    =              512.000 / Field of view in Solar Y (arcsec)
# EISTFLXS=                    1 / Sign - EIS Transl. of XRT Flare X (0=Pos. 1=Neg
# EISTXFLX=                32767 / EIS Transl. of XRT Flare X-coord. (arcsec)
# EISTFLYS=                    1 / Sign - EIS Transl of XRT Flare Y (0=Pos. 1= Neg
# EISTXFLY=                32767 / EIS Transl. of XRT Flare Y-coord. (arcsec)
# EISFLTX =                65535 / EIS flare trigger X-coordinate
# EISFLTY =                65535 / EIS flare trigger Y-coordinate
# EISEVTX =                65535 / EIS event trigger X-location
# EISEVTY =                65535 / EIS event trigger Y-coordinate
# ASRCDIR =                    0 / Anti Solar Rot. Comp. dir. (0=forw, 1=backw)
# ASRCNR  =                    0 / ASRC number of FMIR steps
# ASRCSKIP=                    0 / ASRC frequency
# CAL_DC  =                    1 / Calibration status (Dark Current). 0 = not done
# CAL_HP  =                    1 / Calibration status (Hot pixels). 0 = not done,
# CAL_DP  =                    1 / Calibration status (Dusty pixels). 0 = not done
# CAL_WP  =                    1 /
# CAL_CR  =                    1 / Calibration status (Cosmic rays). 0 = not done,
# CAL_ABS =                    1 / Calibration status (Photometric). 0 = not done,
# CAL_PHOT=                    0 / Calibration status (Photons). 0 = not done, 1 =
# CAL_SENS=                    0 /
# CAL_RETA=                    0 / Calibration status (Retain pixels less than 0).
# BITC_VER=                    7 / Bit compression mode
# COMPMOD =                    7 / Image compression mode
# ACHF_VER=                    1 / Huffman AC table
# DCHF_VER=                    1 / Huffman DC table
# QTAB_VER=                    1 / Quantization table
# SAA     = 'NA      '           / Indicates if satellite is in SAA or not
# HLZ     = 'NA      '           / Indicates if satellite is in HLZ or not
# XOCB    =                    1 / On chip binning x-dir
# YOCB    =                    1 / On chip binning y-dir
# RONCCDAR=                    T / CCD-A Right read out node selected
# RONCCDAL=                    T / CCD-A Left read out node selected
# RONCCDBR=                    T / CCD-B Right read out node selected
# RONCCDBL=                    T / CCD-B Left read out node selected
# XRTFLTR =                    F / XRT Flare Trigger Status (T enabled, F disabled
# EISAEC  =                    F / EIS AEC Status (T enabled, F disabled)
# EISEVTR =                    F / EIS Event Trigger Status (T enabled, F disabled
# EISFLTR =                    F / EIS Flare Trigger Status (T enabled, F disabled
# RESCUED =                    F / Missing or corrupted data (T or F)

# %%
data = hdul[1].data

# %%
hdul[1].header
# Out:
# XTENSION= 'BINTABLE'           / Written by IDL:  Wed Jun 10 17:46:26 2020
# BITPIX  =                    8 /
# NAXIS   =                    2 / Binary table
# NAXIS1  =              8388693 / Number of bytes per row
# NAXIS2  =                    3 / Number of rows
# PCOUNT  =                    0 / Random parameter count
# GCOUNT  =                    1 / Group count
# TFIELDS =                   25 / Number of columns
# DATE    = '2020-06-10'         /
# ORIGIN  = 'ISAS    '           / Institute where FITS file was written
# DATA_LEV=                    1 / FITS Level (0, 1, 2)
# DATE_RF0= '2020-06-10T08:46:25.568' / Date and time of Level 0 reformat
# ORIG_RF0= 'ISAS    '           / Institution where Level 0 reformat was done
# VER_RF0 = 'EIS_Lev0_Reformatter $Revision: 391 $' / Fits Level 0 reformatter ver
# DATE_RF1= '2020-06-16T14:10:42.612' / Date and time of Level 1 reformat
# ORIG_RF1= 'ITA-UiO '           / Institution where Level 1 reformat was done
# VER_RF1 = 'EIS_prep Ver $Revision: 748 $' / Fits Level 1 reformatter version no.
# TELESCOP= 'Hinode  '           / Telescope (Solar-B)
# INSTRUME= 'EIS     '           / EUV Imaging Spectrometer
# LONGSTRN= 'OGIP 1.0'           / The OGIP long string convention may be used.
# COMMENT This FITS file may contain long string keyword values that are
# COMMENT continued over multiple keywords.  This convention uses the  '&'
# COMMENT character at the end of a string which is then continued
# COMMENT on subsequent keywords whose name = 'CONTINUE'.
# OBSTITLE= 'Ultra deep exposure coronal hole                                   &'
# CONTINUE  '             ' / Title of the observation
# TARGET  = 'Coronal Hole        ' / Observation region (QS, CH, AR, FS)
# NOAA_NUM=                    0 / Active region NOAA number
# SCI_OBJ = 'CH                                                                 &'
# CONTINUE  '             ' / Target phenomena for this observation
# OBS_DEC = 'Full CCD, 3x600s, 2"x512", 27 reps off disk                        &'
# CONTINUE  '             ' / Properties of the observation
# JOIN_SB = 'E         '         / Joint observation indicator
# OBS_NUM =                    0 / Sequential number of Solar-B observation
# JOP_ID  =                    0 / Joint observing program number
# RAST_ACR= 'EL_WHI_CH_limb'     / Raster Acronym
# STUD_ACR= 'EL_WHI_CH_limb      ' / Study Acronym
# LL_ACR  = 'EL_full_CCD_readout' / Line List Acronym
# LL_ID   =                   41 / Line List ID
# STUDY_ID=                  264 / Study ID
# ST_AUTH = 'Enrico Landi        ' / Study Author
# OBSERVER= 'None                          ' / Chief observer name
# PLANNER = 'None                          ' / Name of Chief Planner
# TOHBANS = 'None           '    / Name of RT Tohbans
# DATATYPE= 'Science             ' / Type of data (pixel data or moments)
# TIMESYS = 'UTC     '           / Time system used in FITS file
# MAIN_ID =                  321 / Main ID
# MDPACK  =                    8 / Number of telemetry packets per exposure
# SEQ_NR  =                   19 / Sequence table number
# SLIT_NR =                33027 / Slit number
# SLIT_IND=                    2 / Slit index
# SLIT_ID = '2"      '           / Slit ID
# LL_NR   =                   13 / Line list number
# NWIN    =                    4 / Number of line windows
# REC_TLID=                21513 / Received timeline entry id
# TL_ID   =                21513 / Unique number for each timeline entry
# TL_WRAP = 'False   '           / True if the on-board timeline id has wrapped
# PLAN_TL =                21513 / Timeline id entry generated by the PT
# RAST_ID =                  253 / Unique number for each raster
# FMIR_SS =                    0 / Fine mirror step size (0 for sit-and-stare mode
# NEXP    =                    3 / Number of exposures performed in raster
# RAST_REQ=                    3 / Number of raster exposures required
# NEXP_PRP=                    3 / Number of exposures pr raster position
# NRASTER =                    1 / Number of unique raster positions
# CCDXL   =                 2148 / CCD X-length incl. scan pix
# XWS     =                   50 / HW (Cam) x window start
# XW      =                 1024 / HW (Cam) x window length
# YWS     =                    2 / HW (Cam) y window start
# YW      =                  512 / HW (Cam) y window height
# RREP_REQ=                   20 / Number of raster repeats required
# RREP_PFD=                   11 / Number of raster repeats performed
# SREP_REQ=                    1 / Number of sequence repeats required
# SREP_PFD=                    1 / Number of sequence repeats performed
# DATE_OBS= '2011-03-06T00:05:01.000' / Start date/time of observation
# DATE_END= '2011-03-06T00:35:05.000' / End date/time of observation
# OBT_TIME=           3221624572 / Spacecraft start time (TI (mdp) units)
# OBT_END =           3222548285 / Spacecraft end time (TI (mdp) units)
# CCSDS_OB= '2011-03-06T00:15:09.000' / Time of first CCSDS packet
# CCSDS_EN= '2011-03-06T00:36:25.000' / Time of last CCSDS packet
# CCSDS_TI=            201411810 / Time of last CCSDS packet (TI (dhu) units)
# XCEN    =            -0.618851 / Center pointing (Solar X)
# YCEN    =             -1242.67 / Center pointing (Solar Y)
# CMIRR   =                47659 / Coarse mirror position in unknown units
# CALSTAT = 'DC CR HP WP DP ABS' / Calibration status
# CRPIX1  =                    1 / Reference pixel in solar-x
# CRPIX2  =                    1 / Reference pixel in solar-y
# CRVAL1  =              1.38115 / Coordinate value of CRPIX1
# CRVAL2  =             -1498.17 / Coordinate value of CRPIX2
# CDELT1  =             -2.00000 / Pixel size in solar-x
# CDELT2  =              1.00000 / Pixel size in solar-y
# CDELT3  =            0.0223000 / Pixel size in wavelength (dispersion)
# CUNIT1  = 'arcsec  '           / Definition of data unit for axis 1
# CUNIT2  = 'arcsec  '           / Definition of data unit for axis 2
# CUNIT3  = 'Angstrom'           / Definition of data unit for axis 3
# CTYPE1  = 'Solar-X '           / Label for axis 1
# CTYPE2  = 'Solar-Y '           / Label for axis 2
# CTYPE3  = 'Wavelength'         / Label for axis 3
# TR_MODE = 'FIX     '           / Spacecraft/instrument tracking mode
# INST_ROT=              0.00000 / Instrument rotation angle
# SAT_ROT =              360.000 / Satellite rotation angle
# CROTA1  =              360.000 / INST_ROT + SAT_ROT
# CROTA2  =              360.000 / INST_ROT + SAT_ROT
# FOVX    =              2.00000 / Field of view in Solar X (arcsec)
# FOVY    =              512.000 / Field of view in Solar Y (arcsec)
# EISTFLXS=                    1 / Sign - EIS Transl. of XRT Flare X (0=Pos. 1=Neg
# EISTXFLX=                32767 / EIS Transl. of XRT Flare X-coord. (arcsec)
# EISTFLYS=                    1 / Sign - EIS Transl of XRT Flare Y (0=Pos. 1= Neg
# EISTXFLY=                32767 / EIS Transl. of XRT Flare Y-coord. (arcsec)
# EISFLTX =                65535 / EIS flare trigger X-coordinate
# EISFLTY =                65535 / EIS flare trigger Y-coordinate
# EISEVTX =                65535 / EIS event trigger X-location
# EISEVTY =                65535 / EIS event trigger Y-coordinate
# ASRCDIR =                    0 / Anti Solar Rot. Comp. dir. (0=forw, 1=backw)
# ASRCNR  =                    0 / ASRC number of FMIR steps
# ASRCSKIP=                    0 / ASRC frequency
# CAL_DC  =                    1 / Calibration status (Dark Current). 0 = not done
# CAL_HP  =                    1 / Calibration status (Hot pixels). 0 = not done,
# CAL_DP  =                    1 / Calibration status (Dusty pixels). 0 = not done
# CAL_WP  =                    1 /
# CAL_CR  =                    1 / Calibration status (Cosmic rays). 0 = not done,
# CAL_ABS =                    1 / Calibration status (Photometric). 0 = not done,
# CAL_PHOT=                    0 / Calibration status (Photons). 0 = not done, 1 =
# CAL_SENS=                    0 /
# CAL_RETA=                    0 / Calibration status (Retain pixels less than 0).
# BITC_VER=                    7 / Bit compression mode
# COMPMOD =                    7 / Image compression mode
# ACHF_VER=                    1 / Huffman AC table
# DCHF_VER=                    1 / Huffman DC table
# QTAB_VER=                    1 / Quantization table
# SAA     = 'NA      '           / Indicates if satellite is in SAA or not
# HLZ     = 'NA      '           / Indicates if satellite is in HLZ or not
# XOCB    =                    1 / On chip binning x-dir
# YOCB    =                    1 / On chip binning y-dir
# RONCCDAR=                    T / CCD-A Right read out node selected
# RONCCDAL=                    T / CCD-A Left read out node selected
# RONCCDBR=                    T / CCD-B Right read out node selected
# RONCCDBL=                    T / CCD-B Left read out node selected
# XRTFLTR =                    F / XRT Flare Trigger Status (T enabled, F disabled
# EISAEC  =                    F / EIS AEC Status (T enabled, F disabled)
# EISEVTR =                    F / EIS Event Trigger Status (T enabled, F disabled
# EISFLTR =                    F / EIS Flare Trigger Status (T enabled, F disabled
# RESCUED =                    F / Missing or corrupted data (T or F)
# EXTNAME = 'DATA    '           / Binary Table Extension Data
# TFORM1  = '524288E '           / Real*4 (floating point)
# TTYPE1  = 'Fe X 177.720'       / Data window
# TDIM1   = '(1024,512)'         / Array dimensions for column 1
# TUNIT1  = 'ADC     '           / Units of column 1
# TDMIN1  =              0.00000 / Minimum value in column 1
# TDMAX1  =              103551. / Maximum value in column 1
# TDESC1  = '(Wavelength, solar_x, solar_y)' / Axis labels for column 1
# TCUNI1  = '(Angstrom, arcsec, arcsec)' / Axis units for column 1
# TDETX1  =                   50 / detector start column
# TDETXW1 =                 1024 / Line width (x) in pixels
# TDETY1  =                    2 / Detector start row
# TDELT1  = '(0.022318068,1.00000,1.00000)' / Axis increments
# TWAVE1  =        166.403430861 / Principal wavelength in Angstrom
# TWMIN1  =        166.403430861 / Preliminary minimum wavelength in Angstrom
# TWMAX1  =        189.220244631 / Preliminary maximum wavelength in Angstrom
# TWBND1  = 'B       '           / Wavelength band
# WINHDR1 =                    3 / Line window hdr
# CCDRON1 =                    3 / CCD Read Out Node
# TFORM2  = '524288E '           / Real*4 (floating point)
# TTYPE2  = 'Fe XII 195.120'     / Data window
# TDIM2   = '(1024,512)'         / Array dimensions for column 2
# TUNIT2  = 'ADC     '           / Units of column 2
# TDMIN2  =              0.00000 / Minimum value in column 2
# TDMAX2  =              43297.3 / Maximum value in column 2
# TDESC2  = '(Wavelength, solar_x, solar_y)' / Axis labels for column 2
# TCUNI2  = '(Angstrom, arcsec, arcsec)' / Axis units for column 2
# TDETX2  =                 1074 / detector start column
# TDETXW2 =                 1024 / Line width (x) in pixels
# TDETY2  =                    2 / Detector start row
# TDELT2  = '(0.022318068,1.00000,1.00000)' / Axis increments
# TWAVE2  =        189.242535470 / Principal wavelength in Angstrom
# TWMIN2  =        189.242535470 / Preliminary minimum wavelength in Angstrom
# TWMAX2  =        212.032778503 / Preliminary maximum wavelength in Angstrom
# TWBND2  = 'B       '           / Wavelength band
# WINHDR2 =                    2 / Line window hdr
# CCDRON2 =                    2 / CCD Read Out Node
# TFORM3  = '524288E '           / Real*4 (floating point)
# TTYPE3  = 'He II 256.320'      / Data window
# TDIM3   = '(1024,512)'         / Array dimensions for column 3
# TUNIT3  = 'ADC     '           / Units of column 3
# TDMIN3  =              0.00000 / Minimum value in column 3
# TDMAX3  =              15865.4 / Maximum value in column 3
# TDESC3  = '(Wavelength, solar_x, solar_y)' / Axis labels for column 3
# TCUNI3  = '(Angstrom, arcsec, arcsec)' / Axis units for column 3
# TDETX3  =                 2198 / detector start column
# TDETXW3 =                 1024 / Line width (x) in pixels
# TDETY3  =                    2 / Detector start row
# TDELT3  = '(0.022336000,1.00000,1.00000)' / Axis increments
# TWAVE3  =        245.900979265 / Principal wavelength in Angstrom
# TWMIN3  =        245.900979265 / Preliminary minimum wavelength in Angstrom
# TWMAX3  =        268.676999621 / Preliminary maximum wavelength in Angstrom
# TWBND3  = 'A       '           / Wavelength band
# WINHDR3 =                    1 / Line window hdr
# CCDRON3 =                    1 / CCD Read Out Node
# TFORM4  = '524288E '           / Real*4 (floating point)
# TTYPE4  = 'Fe XV 284.160'      / Data window
# TDIM4   = '(1024,512)'         / Array dimensions for column 4
# TUNIT4  = 'ADC     '           / Units of column 4
# TDMIN4  =              0.00000 / Minimum value in column 4
# TDMAX4  =              1986.15 / Maximum value in column 4
# TDESC4  = '(Wavelength, solar_x, solar_y)' / Axis labels for column 4
# TCUNI4  = '(Angstrom, arcsec, arcsec)' / Axis units for column 4
# TDETX4  =                 3222 / detector start column
# TDETXW4 =                 1024 / Line width (x) in pixels
# TDETY4  =                    2 / Detector start row
# TDELT4  = '(0.022336000,1.00000,1.00000)' / Axis increments
# TWAVE4  =        268.699249956 / Principal wavelength in Angstrom
# TWMIN4  =        268.699249956 / Preliminary minimum wavelength in Angstrom
# TWMAX4  =        291.447414019 / Preliminary maximum wavelength in Angstrom
# TWBND4  = 'A       '           / Wavelength band
# WINHDR4 =                    0 / Line window hdr
# CCDRON4 =                    0 / CCD Read Out Node
# TFORM5  = '1D      '           / Real*8 (double precision)
# TTYPE5  = 'TI_1    '           / Shutter open time
# TUNIT5  = 'TI      '           / Units of column 5
# TDMIN5  =        3221624572.00 / Minimum value in column 5
# TDMAX5  =        3222241019.00 / Maximum value in column 5
# TFORM6  = '1D      '           / Real*8 (double precision)
# TTYPE6  = 'TI_2    '           / Shutter close time
# TUNIT6  = 'TI      '           / Units of column 6
# TDMIN6  =        3221931888.00 / Minimum value in column 6
# TDMAX6  =        3222548285.00 / Maximum value in column 6
# TFORM7  = '1D      '           / Real*8 (double precision)
# TTYPE7  = 'mhc_dur '           / Exposure duration as measured by the MHC
# TUNIT7  = '1 microsec'         / Units of column 7
# TDMIN7  =        600000145.000 / Minimum value in column 7
# TDMAX7  =        600000687.000 / Maximum value in column 7
# TFORM8  = '1D      '           / Real*8 (double precision)
# TTYPE8  = 'exp_dur '           / Exposure time as specified by the sequence
# TUNIT8  = '10 ms   '           / Units of column 8
# TDMIN8  =        4294961760.00 / Minimum value in column 8
# TDMAX8  =        4294961760.00 / Maximum value in column 8
# TFORM9  = '1I      '           / Integer*2 (short integer)
# TTYPE9  = 'fmirr   '           / Fine mirrror position
# TUNIT9  = '0.1248 arcsec'      / Units of column 9
# TDMIN9  =                 1769 / Minimum value in column 9
# TDMAX9  =                 1769 / Maximum value in column 9
# TFORM10 = '1I      '           / Integer*2 (short integer)
# TTYPE10 = 'hslstat '           / HSL Status
# TUNIT10 = 'integer '           / Units of column 10
# TFORM11 = '1B      '           / Integer*1 (byte)
# TTYPE11 = 'xrt_flfl'           / XRT Flare Flag Received
# TUNIT11 = '0 or 1  '           / Units of column 11
# TDMIN11 =                    0 / Minimum value in column 11
# TDMAX11 =                    0 / Maximum value in column 11
# TFORM12 = '1B      '           / Integer*1 (byte)
# TTYPE12 = 'xrt_fl_x'           / XRT Flare X-Coordinate
# TUNIT12 = 'arcsec? (byte)'     / Units of column 12
# TDMIN12 =                  177 / Minimum value in column 12
# TDMAX12 =                  177 / Maximum value in column 12
# TFORM13 = '1B      '           / Integer*1 (byte)
# TTYPE13 = 'xrt_fl_y'           / XRT Flare Y-Coordinate
# TUNIT13 = 'arcsec? (byte)'     / Units of column 13
# TDMIN13 =                   41 / Minimum value in column 13
# TDMAX13 =                   41 / Maximum value in column 13
# TFORM14 = '1J      '           / Integer*4 (long integer)
# TTYPE14 = 'aec_hepc'           / AEC High Energy Pixel Count
# TUNIT14 = '32 bit long'        / Units of column 14
# TDMIN14 =                   -1 / Minimum value in column 14
# TDMAX14 =                   -1 / Maximum value in column 14
# TFORM15 = '1J      '           / Integer*4 (long integer)
# TTYPE15 = 'aec_lepc'           / AEC Low Energy Pixel Count
# TUNIT15 = '32 bit long'        / Units of column 15
# TDMIN15 =                   -1 / Minimum value in column 15
# TDMAX15 =                   -1 / Maximum value in column 15
# TFORM16 = '1I      '           / Integer*2 (short integer)
# TTYPE16 = 'mhcfmsgo'           / MHC Fine Mirror Strain Gauge output
# TUNIT16 = '? integer'          / Units of column 16
# TDMIN16 =                 1976 / Minimum value in column 16
# TDMAX16 =                 1977 / Maximum value in column 16
# TFORM17 = '1E      '           / Real*4 (floating point)
# TTYPE17 = 'XCEN_TI1'           / Center pointing (Solar X(TI_1) )
# TUNIT17 = 'arcsec  '           / Units of column 17
# TDMIN17 =       -145.435760498 / Minimum value in column 17
# TDMAX17 =       -145.358520508 / Maximum value in column 17
# TFORM18 = '1E      '           / Real*4 (floating point)
# TTYPE18 = 'YCEN_TI1'           / Center pointing (Solar Y(TI_1) )
# TUNIT18 = 'arcsec  '           / Units of column 18
# TDMIN18 =       -974.422245979 / Minimum value in column 18
# TDMAX18 =       -974.346333742 / Maximum value in column 18
# TFORM19 = '1E      '           / Real*4 (floating point)
# TTYPE19 = 'CCDAT_TI'           / CCD A temperature (CCDA_T(TI_1) )
# TUNIT19 = 'C       '           / Units of column 19
# TDMIN19 =             -44.3519 / Minimum value in column 19
# TDMAX19 =             -42.2036 / Maximum value in column 19
# TFORM20 = '1E      '           / Real*4 (floating point)
# TTYPE20 = 'CCDBT_TI'           / CCD B temperature (CCDB_T(TI_1) )
# TUNIT20 = 'C       '           / Units of column 20
# TDMIN20 =             -44.3519 / Minimum value in column 20
# TDMAX20 =             -44.3519 / Maximum value in column 20
# TFORM21 = '1E      '           / Real*4 (floating point)
# TTYPE21 = 'MHC_HZ_T10'         / MHC HZ TEMP 10 (MHC_T10(TI) )
# TUNIT21 = 'C       '           / Units of column 21
# TDMIN21 =              19.5891 / Minimum value in column 21
# TDMAX21 =              19.6920 / Maximum value in column 21
# TFORM22 = '1E      '           / Real*4 (floating point)
# TTYPE22 = 'MHC_HZ_T15'         / MHC HZ TEMP 15 (MHC_T15(TI) )
# TUNIT22 = 'C       '           / Units of column 22
# TDMIN22 =              18.7412 / Minimum value in column 22
# TDMAX22 =              18.8472 / Maximum value in column 22
# TFORM23 = '1E      '           / Real*4 (floating point)
# TTYPE23 = 'V_SAT   '           / Satellite Doppler vel (V_SAT)
# TUNIT23 = 'm/s     '           / Units of column 23
# TDMIN23 =             -1168.00 / Minimum value in column 23
# TDMAX23 =             -349.000 / Maximum value in column 23
# TFORM24 = '1E      '           / Real*4 (floating point)
# TTYPE24 = 'V_SUN   '           / Sun Doppler vel (V_SUN)
# TUNIT24 = 'm/s     '           / Units of column 24
# TDMIN24 =             -24.0000 / Minimum value in column 24
# TDMAX24 =             -24.0000 / Maximum value in column 24
# TFORM25 = '1E      '           / Real*4 (floating point)
# TTYPE25 = 'V_ETH   '           / Earth Doppler vel (V_ETH)
# TUNIT25 = 'm/s     '           / Units of column 25
# TDMIN25 =              437.000 / Minimum value in column 25
# TDMAX25 =              437.000 / Maximum value in column 25
