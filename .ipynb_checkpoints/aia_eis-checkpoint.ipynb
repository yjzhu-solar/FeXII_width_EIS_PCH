# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
from matplotlib import colors
from matplotlib import ticker
from matplotlib import rcParams
from matplotlib import patches
import xarray as xr
import scipy.io
import astropy.constants as const
rcParams['text.usetex'] = True
rcParams['font.family'] = 'serif'
from astropy.io import fits
import pandas as pd
import sunpy.visualization.colormaps as cm
sdoaia193 = plt.get_cmap('sdoaia193')

# %%
sav_0305 = scipy.io.readsav('../src/aia_lvl15/20110305.sav',verbose = False,python_dict=True)
sav_0306 = scipy.io.readsav('../src/aia_lvl15/20110306.sav',verbose = False,python_dict=True)
sav_0311 = scipy.io.readsav('../src/aia_lvl15/20110311.sav',verbose = False,python_dict=True)

# %%
data_0305 = sav_0305['out_data']
header_0305 = sav_0305['out_index']
data_0306 = sav_0306['out_data']
header_0306 = sav_0306['out_index']
data_0311 = sav_0311['out_data']
header_0311 = sav_0311['out_index']

# %%
data_0305.shape
# Out:
# (10, 2048, 3582)

# %%
hdul = fits.open("../src/aia_lvl15/AIA20110305_184507_0193.fits")
hdul[0].header
# Out:
# SIMPLE  =                    T / Written by IDL:  Tue Jul 28 05:27:14 2020
# BITPIX  =                   16 / Integer*2 (short integer)
# NAXIS   =                    2 /
# NAXIS1  =                 3582 /
# NAXIS2  =                 2048 /
# BLD_VERS= 'V5R12X  '           /
# LVL_NUM =        1.50000000000 /
# T_REC   = '2011-03-05T18:45:09Z' /
# TRECSTEP=        1.00000000000 /
# TRECEPOC= '1977.01.01_00:00:00_TAI' /
# TRECROUN=                    1 /
# ORIGIN  = 'SDO     '           /
# DATE    = '2020-07-16T02:42:12' /
# TELESCOP= 'SDO     '           /
# INSTRUME= 'AIA_2   '           /
# DATE-OBS= '2011-03-05T18:45:07.84' /
# T_OBS   = '2011-03-05T18:45:08.84Z' /
# CAMERA  =                    2 /
# IMG_TYPE= 'LIGHT   '           /
# EXPTIME =        1.99966800000 /
# EXPSDEV =    0.000112000000000 /
# INT_TIME=        2.27343800000 /
# WAVELNTH=                  193 /
# WAVEUNIT= 'angstrom'           /
# WAVE_STR= '193_THIN'           /
# FSN     =             21857651 /
# FID     =                    0 /
# QUALLEV0=                    0 /
# QUALITY =                    0 /
# TOTVALS =             16777216 /
# DATAVALS=             16777216 /
# MISSVALS=                    0 /
# PERCENTD=        100.000000000 /
# DATAMIN =                   -5 /
# DATAMAX =                14333 /
# DATAMEDN=                  188 /
# DATAMEAN=        285.348236084 /
# DATARMS =        43499077632.0 /
# DATASKEW=        5.48879766464 /
# DATAKURT=        46.2856025696 /
# DATACENT=        283.310000000 /
# DATAP01 =        0.00000000000 /
# DATAP10 =        11.0000000000 /
# DATAP25 =        38.0000000000 /
# DATAP75 =        358.000000000 /
# DATAP90 =        679.000000000 /
# DATAP95 =        1046.00000000 /
# DATAP98 =        1718.00000000 /
# DATAP99 =        2392.00000000 /
# NSATPIX =                    2 /
# OSCNMEAN= 'nan     '           /
# OSCNRMS = 'nan     '           /
# FLAT_REC= 'aia.flatfield[:#10]' /
# NSPIKES =                12971 /
# CTYPE1  = 'HPLN-TAN'           /
# CUNIT1  = 'arcsec  '           /
# CRVAL1  =        0.00000000000 /
# CDELT1  =       0.600714055060 /
# CRPIX1  =        1795.92004400 /
# CTYPE2  = 'HPLT-TAN'           /
# CUNIT2  = 'arcsec  '           /
# CRVAL2  =        0.00000000000 /
# CDELT2  =       0.600714055060 /
# CRPIX2  =        2041.26001000 /
# CROTA2  =      0.0579399950373 /
# R_SUN   =        1610.03211061 /
# MPO_REC = 'sdo.master_pointing[:#113]' /
# INST_ROT=       0.135679000000 /
# IMSCL_MP=       0.600299000000 /
# X0_MP   =        2044.92004400 /
# Y0_MP   =        2040.26001000 /
# ASD_REC = 'sdo.lev0_asd_0004[:#8652738]' /
# SAT_Y0  =       -7.59131300000 /
# SAT_Z0  =        8.66116300000 /
# SAT_ROT =    0.000151000000000 /
# ACS_MODE= 'SCIENCE '           /
# ACS_ECLP= 'NO      '           /
# ACS_SUNP= 'YES     '           /
# ACS_SAFE= 'NO      '           /
# ACS_CGT = 'GT3     '           /
# ORB_REC = 'sdo.fds_orbit_vectors[2011.03.05_18:45:00_UTC]' /
# DSUN_REF=        149597870691. /
# DSUN_OBS=        148341947386. /
# RSUN_REF=        696000000.000 /
# RSUN_OBS=        967.769632000 /
# GAEX_OBS=        40073403.3000 /
# GAEY_OBS=       -7563904.49000 /
# GAEZ_OBS=        10733446.8900 /
# HAEX_OBS=       -143075380356. /
# HAEY_OBS=        39176125345.4 /
# HAEZ_OBS=        9658402.68000 /
# OBS_VR  =      -0.961306000000 /
# OBS_VW  =        28006.4516920 /
# OBS_VN  =       -2337.53929400 /
# CRLN_OBS=        135.461716000 /
# CRLT_OBS=       -7.24499100000 /
# CAR_ROT =                 2107 /
# HGLN_OBS=        0.00000000000 /
# HGLT_OBS=       -7.24499100000 /
# ROI_NWIN=          -2147483648 /
# ROI_SUM =          -2147483648 /
# ROI_NAX1=          -2147483648 /
# ROI_NAY1=          -2147483648 /
# ROI_LLX1=          -2147483648 /
# ROI_LLY1=          -2147483648 /
# ROI_NAX2=          -2147483648 /
# ROI_NAY2=          -2147483648 /
# ROI_LLX2=          -2147483648 /
# ROI_LLY2=          -2147483648 /
# PIXLUNIT= 'DN      '           /
# DN_GAIN =        18.3000000000 /
# EFF_AREA=        1.18800000000 /
# EFF_AR_V=        1.00000000000 /
# TEMPCCD =       -67.4000000000 /
# TEMPGT  =        15.1330000000 /
# TEMPSMIR=        32.3930000000 /
# TEMPFPAD=        17.7960000000 /
# ISPSNAME= 'aia.lev0_isp_0011'  /
# ISPPKTIM= '2011-03-05T18:45:05.00Z' /
# ISPPKTVN= '001.197 '           /
# AIVNMST =                  453 /
# AIMGOTS =           1678041942 /
# ASQHDR  =           1095599475 /
# ASQTNUM =                    1 /
# ASQFSN  =             21857651 /
# AIAHFSN =             21857643 /
# AECDELAY=                 1526 /
# AIAECTI =                    0 /
# AIASEN  =                    6 /
# AIFDBID =                  241 /
# AIMGOTSS=                37688 /
# AIFCPS  =                   55 /
# AIFTSWTH=                    0 /
# AIFRMLID=                 3024 /
# AIFTSID =                40960 /
# AIHISMXB=                    7 /
# AIHIS192=              8349567 /
# AIHIS348=              8385615 /
# AIHIS604=              8388488 /
# AIHIS860=              8388590 /
# AIFWEN  =                  270 /
# AIMGSHCE=                 2000 /
# AECTYPE =                    0 /
# AECMODE = 'ON      '           /
# AISTATE = 'CLOSED  '           /
# AIAECENF=                    1 /
# AIFILTYP=                    0 /
# AIMSHOBC=        41.6320000000 /
# AIMSHOBE=        26.7320000000 /
# AIMSHOTC=        55.8079990000 /
# AIMSHOTE=        69.8399960000 /
# AIMSHCBC=        2041.44397000 /
# AIMSHCBE=        2026.23596200 /
# AIMSHCTC=        2055.52002000 /
# AIMSHCTE=        2069.48388700 /
# AICFGDL1=                    0 /
# AICFGDL2=                  137 /
# AICFGDL3=                  201 /
# AICFGDL4=                  236 /
# AIFOENFL=                    1 /
# AIMGFSN =                    2 /
# AIMGTYP =                    0 /
# AIAWVLEN=                    3 /
# AIAGP1  =                    0 /
# AIAGP2  =                    0 /
# AIAGP3  =                    0 /
# AIAGP4  =                    0 /
# AIAGP5  =                    0 /
# AIAGP6  =                    0 /
# AIAGP7  =                    0 /
# AIAGP8  =                  393 /
# AIAGP9  =                  457 /
# AIAGP10 =                  748 /
# AGT1SVY =                   -3 /
# AGT1SVZ =                    4 /
# AGT2SVY =                   -6 /
# AGT2SVZ =                   -6 /
# AGT3SVY =                    0 /
# AGT3SVZ =                    0 /
# AGT4SVY =                   -4 /
# AGT4SVZ =                   -9 /
# AIMGSHEN=                    4 /
# KEYWDDOC= 'http:   '           /
# RECNUM  =              8862676 /
# BLANK   =               -32768 /
# CHECKSUM= 'bgYkbZWhbfWhbZWh'   / HDU checksum updated 2020-07-28T09:27:15
# DATASUM = '3264128044'         / data unit checksum updated 2020-07-28T09:27:15
# DATE_OBS= '2011-03-05T18:45:07.84' /
# XCEN    =       -2.65518255479 /
# YCEN    =       -610.782028630 /
# SSWJOBID= 'ssw_service_200715_193702_6047' /
# COMMENT FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# COMMENT FITSHEAD2STRUCT
# COMMENT FITSHEAD2STRUCT
# HISTORY FITSHEAD2STRUCT run at: Wed Jul 15 19:42:11 2020
# HISTORY mreadfits_shm VERSION:  1.20
# HISTORY read_sdo VERSION:  2.10
# HISTORY read_sdo  xll,xyy,nx,ny: 251,251,251,251,251,251,251,251,251,251,1,1,1,1
# HISTORY read_sdo  Orig FILE: /SUM77/D143555540/S00000/image_lev1.fits
# HISTORY read_sdo  Orig DATE: 2011-03-09T09:46:44
# HISTORY read_sdo  fovx,fovy: 2150.2710,1229.4124
# HISTORY read_sdo  Orig CRPIX1,CRPIX2: 2045.9200,2041.2600
# HISTORY read_sdo  Orig CDELT1,CDELT2: 0.60029900,0.60029900
# HISTORY read_sdo  Orig CROTA2: 0.13583000
# HISTORY ssw_service_track_fov VERSION:  2.10
# HISTORY ssw_service_track_fov  jobid: ssw_service_200715_193702_6047
# HISTORY ssw_service_track_fov  ref_info: @
# HISTORY ssw_service_track_fov  xll,xyy,nx,ny: 251,1,3582,2048
# HISTORY ssw_service_track_fov  fovx,fovy: 2150.00,1229.00
# HISTORY ssw_service_track_fov  Orig CRPIX1&2: 2045.9200,2041.2600
# HISTORY ssw_service_track_fov  CFITSIO adjusted
# HISTORY FITSHEAD2STRUCT run at: Tue Jul 28 05:26:19 2020
# HISTORY mreadfits_shm VERSION:  1.20
# HISTORY read_sdo VERSION:  2.10
# HISTORY aia2wcsmin.pro VERSION:  5.10
# HISTORY aia2wcsmin
# HISTORY aia2wcsmin  MPO_date: 2012-09-04T00:00:00Z
# HISTORY aia2wcsmin  MPO_t_start: 2011-02-28T19:10:00Z
# HISTORY aia2wcsmin  MPO_t_stop: 2011-03-06T00:00:00Z
# HISTORY aia2wcsmin  MPO_version: 5
# HISTORY ssw_reg.pro VERSION:  1.30
# HISTORY ssw_reg
# HISTORY ssw_reg  ROT called with cubic interpolation: cubic = -0.500000
# HISTORY ssw_reg  Image registered to SDO image with FSN = 21857651
# HISTORY ssw_reg  Image registered to SDO image with T_OBS = 2011-03-05T18:45:08.
# HISTORY aia_fix_header.pro VERSION:  1.00
# HISTORY aia_prep.pro VERSION:  5.10
# HISTORY aia_reg.pro VERSION:  1.20

# %%
header_0305[0]
# Out:
# (1, 16, 2, 3582, 2048, b'V5R12X', 1.5, b'2011-03-05T18:45:09Z', 1., b'1977.01.01_00:00:00_TAI', 1, b'SDO', b'2020-07-16T02:42:12', b'SDO', b'AIA_2', b'2011-03-05T18:45:07.84', b'2011-03-05T18:45:08.84Z', 2, b'LIGHT', 1.999668, 0.000112, 2.273438, 193, b'angstrom', b'193_THIN', 21857651, 0, 0, 0, 16777216, 16777216, 0, 100., -5, 14333, 188, 285.34823608, 4.34990776e+10, 5.48879766, 46.28560257, 283.31, 0., 11., 38., 358., 679., 1046., 1718., 2392., 2, b'nan', b'nan', b'aia.flatfield[:#10]', 12971, b'HPLN-TAN', b'arcsec', 0., 0.60071406, 1795.920044, b'HPLT-TAN', b'arcsec', 0., 0.60071406, 2041.26001, 0.05794, 1610.03211061, b'sdo.master_pointing[:#113]', 0.135679, 0.600299, 2044.920044, 2040.26001, b'sdo.lev0_asd_0004[:#8652738]', -7.591313, 8.661163, 0.000151, b'SCIENCE', b'NO', b'YES', b'NO', b'GT3', b'sdo.fds_orbit_vectors[2011.03.05_18:45:00_UTC]', 1.49597871e+11, 1.48341947e+11, 6.96e+08, 967.769632, 40073403.3, -7563904.49, 10733446.89, -1.4307538e+11, 3.91761253e+10, 9658402.68, -0.961306, 28006.451692, -2337.539294, 135.461716, -7.244991, 2107, 0., -7.244991, -2147483648, -2147483648, -2147483648, -2147483648, -2147483648, -2147483648, -2147483648, -2147483648, -2147483648, -2147483648, b'DN', 18.3, 1.188, 1., -67.4, 15.133, 32.393, 17.796, b'aia.lev0_isp_0011', b'2011-03-05T18:45:05.00Z', b'001.197', 453, 1678041942, 1095599475, 1, 21857651, 21857643, 1526, 0, 6, 241, 37688, 55, 0, 3024, 40960, 7, 8349567, 8385615, 8388488, 8388590, 270, 2000, 0, b'ON', b'CLOSED', 1, 0, 41.632, 26.732, 55.807999, 69.839996, 2041.44397, 2026.235962, 2055.52002, 2069.483887, 0, 137, 201, 236, 1, 2, 0, 3, 0, 0, 0, 0, 0, 0, 0, 393, 457, 748, -3, 4, -6, -6, 0, 0, -4, -9, 4, b'http:', 8862676, -32768, b'S9nAS8k3S8kAS8k3', b'3264128044', b'2011-03-05T18:45:07.84', -2.65518255, -610.78202863, b'ssw_service_200715_193702_6047', array([b"FITS (Flexible Image Transport System) format is defined in 'Astronomy",
#        b"and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H",
#        b'FITSHEAD2STRUCT', b'FITSHEAD2STRUCT', '', '', '', '', '', '', '',
#        '', '', '', '', '', '', '', '', ''], dtype=object), array([b'FITSHEAD2STRUCT run at: Wed Jul 15 19:42:11 2020',
#        b'mreadfits_shm VERSION:  1.20', b'read_sdo VERSION:  2.10',
#        b'read_sdo  xll,xyy,nx,ny: 251,251,251,251,251,251,251,251,251,251,1,1,1,1',
#        b'read_sdo  Orig FILE: /SUM77/D143555540/S00000/image_lev1.fits',
#        b'read_sdo  Orig DATE: 2011-03-09T09:46:44',
#        b'read_sdo  fovx,fovy: 2150.2710,1229.4124',
#        b'read_sdo  Orig CRPIX1,CRPIX2: 2045.9200,2041.2600',
#        b'read_sdo  Orig CDELT1,CDELT2: 0.60029900,0.60029900',
#        b'read_sdo  Orig CROTA2: 0.13583000',
#        b'ssw_service_track_fov VERSION:  2.10',
#        b'ssw_service_track_fov  jobid: ssw_service_200715_193702_6047',
#        b'ssw_service_track_fov  ref_info: @',
#        b'ssw_service_track_fov  xll,xyy,nx,ny: 251,1,3582,2048',
#        b'ssw_service_track_fov  fovx,fovy: 2150.00,1229.00',
#        b'ssw_service_track_fov  Orig CRPIX1&2: 2045.9200,2041.2600',
#        b'ssw_service_track_fov  CFITSIO adjusted',
#        b'FITSHEAD2STRUCT run at: Tue Jul 28 04:34:31 2020', '', '', '',
#        '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
#        '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
#        '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
#        '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '', '',
#        '', b'mreadfits_shm VERSION:  1.20 ', b'read_sdo VERSION:  2.10 ',
#        b'aia2wcsmin.pro VERSION:  5.10 ', b'aia2wcsmin  ',
#        b'aia2wcsmin  MPO_date: 2012-09-04T00:00:00Z',
#        b'aia2wcsmin  MPO_t_start: 2011-02-28T19:10:00Z',
#        b'aia2wcsmin  MPO_t_stop: 2011-03-06T00:00:00Z',
#        b'aia2wcsmin  MPO_version: 5', b'ssw_reg.pro VERSION:  1.30 ',
#        b'ssw_reg  ',
#        b'ssw_reg  ROT called with cubic interpolation: cubic = -0.500000',
#        b'ssw_reg  Image registered to SDO image with FSN = 21857651',
#        b'ssw_reg  Image registered to SDO image with T_OBS = 2011-03-05T18:45:08.84Z',
#        b'aia_fix_header.pro VERSION:  1.00 ',
#        b'aia_prep.pro VERSION:  5.10 ', b'aia_reg.pro VERSION:  1.20 '],
#       dtype=object))

# %%
plt.imshow(np.log10(data_0305[0,:,:]),origin="lower",cmap=sdoaia193)
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
plt.imshow(np.log10(np.mean(data_0305[:,:,:],axis=0)),origin="lower",cmap=sdoaia193,
          extent = [-1795.92 * 0.600714055060, (-1795.92 + 3582) * 0.600714055060,-2041.26 * 0.600714055060,(-2041.26 + 2048) * 0.600714055060])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in log10
#   """Entry point for launching an IPython kernel.
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log10
#   """Entry point for launching an IPython kernel.

# %%
fig, ax = plt.subplots(figsize = (14,10))
ax1 = plt.subplot2grid((4,4),(0,0),rowspan = 2,colspan = 2)
ax2 = plt.subplot2grid((4,4),(0,2),rowspan = 2,colspan = 2)
ax3 = plt.subplot2grid((4,4),(2,1),rowspan = 2,colspan = 2)

vmin, vmax = np.log10(np.percentile(np.mean(data_0305[:,:,:],axis=0),[5,99]))
ax1.imshow(np.log10(np.mean(data_0305[:,:,:],axis=0)),origin="lower",cmap=sdoaia193,vmin=vmin,vmax = vmax,
          extent = [-1795.92 * 0.600714055060, (-1795.92 + 3582) * 0.600714055060,-2041.26 * 0.600714055060,(-2041.26 + 2048) * 0.600714055060])

ax1.set_title("AIA 193 \mbox{\AA} 2011-03-05 18:45",fontsize=16)

ax2.imshow(np.log10(np.mean(data_0306[:,:,:],axis=0)),origin="lower",cmap=sdoaia193,vmin=vmin,vmax=vmax,
          extent = [-1795.92 * 0.600714055060, (-1795.85 + 3582) * 0.600714055060,-2041.26 * 0.600714055060,(-2041.86 + 2048) * 0.600714055060])

ax2.set_title("AIA 193 \mbox{\AA} 2011-03-06 21:15",fontsize=16)

ax3.imshow(np.log10(np.mean(data_0311[:,:,:],axis=0)),origin="lower",cmap=sdoaia193,
          extent = [-1795.92 * 0.600714055060, (-1795.85 + 3582) * 0.600714055060,-2041.26 * 0.600714055060,(-2041.86 + 2048) * 0.600714055060])

ax3.set_title("AIA 193 \mbox{\AA} 2011-03-11 16:00",fontsize=16)

for ax_ in (ax1, ax2, ax3):
    ln, = ax_.plot([0,0],[-842 + 256, -842- 256],color = "white",label="EIS Slit")
    ax_.set_xlabel("Solar-X (arcsec)",fontsize=16)
    ax_.set_ylabel("Solar-Y (arcsec)",fontsize=16)
    ax_.tick_params(labelsize=15)
    ax_.set_yticks([0,-400,-800,-1200])
leg = [ln]
ax1.legend(leg,[leg_.get_label() for leg_ in leg],loc = 'lower left',fontsize = 16)
ax2.yaxis.tick_right()
ax2.yaxis.set_label_position("right")

plt.subplots_adjust(bottom = 0.02,left=0.07,top=1,right=0.92,hspace=-0.02)
plt.savefig(fname = '../figs/aia_eis.pdf', dpi = 300, format = 'pdf')
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: divide by zero encountered in log10
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: RuntimeWarning: invalid value encountered in log10
#   import sys
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: divide by zero encountered in log10
#   if sys.path[0] == '':
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: RuntimeWarning: invalid value encountered in log10
#   if sys.path[0] == '':
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: divide by zero encountered in log10
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: RuntimeWarning: invalid value encountered in log10
